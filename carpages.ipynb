# %% [markdown]
# ----------
#
# <h1 align="center">Webscraping Project - carpages.ca </h1>
# <br>
# <center align="left"> <font size='4'>  Developed by: </font><font size='4' color='#33AAFBD'>Richa Sharma </font></center>
# <br>
#
# ----------

# %% [markdown]
# <h2>Contents</h2>

# %% [markdown]
# 1.-Install and Import Libraries
#
# 2.-Data-Scraping
#
# 3.-Data-Cleanup
#
# 4.-Store the Cleaned Data
#
# 5.-Exploratory Data Analysis

# %% [markdown]
# # 1.-Install and Import Libraries

# %% [markdown]
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/d/d5/Selenium_Logo.png" width='6.5%'></span>
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/White_square_50%25_transparency.svg/500px-White_square_50%25_transparency.svg.png" width='6%'></span>
# <span><img align="left" src="https://pandas.pydata.org/static/img/pandas_secondary.svg" width='10%'></span>
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/White_square_50%25_transparency.svg/500px-White_square_50%25_transparency.svg.png" width='4%'></span>
# <span><img align="left" src="https://matplotlib.org/stable/_images/sphx_glr_logos2_001.png" width='7%'></span>
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/White_square_50%25_transparency.svg/500px-White_square_50%25_transparency.svg.png" width='6%'></span>
# <span><img align="left" src="https://seaborn.pydata.org/_images/logo-tall-lightbg.svg" width='6%'></span>
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/White_square_50%25_transparency.svg/500px-White_square_50%25_transparency.svg.png" width='2%'></span>
# <span><img align="left" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Plotly-logo.png/1200px-Plotly-logo.png" width='22%'></span>
# <span><img align="left" src="https://tarun-kamboj.github.io/images/tools/folium.png" width='7%'></span>

# %%
import requests
from bs4 import BeautifulSoup

# %%
import numpy as np
import pandas as pd
import random
from time import sleep
from tqdm import tqdm # to show a smart progress meter
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
#pip install geopy

# %% [markdown]
# # 2.-Data-Scraping

# %%
#2.1 Setting up Beautiful Soup

# %%
#Access the home page of the website with get() request
page=requests.get('https://www.carpages.ca/used-cars/search/')
print("Status: ",page.status_code)
soup=BeautifulSoup(page.content, 'lxml')
# Out:
# Status:  200

# %%
# Create an empty dictionary with 6 columns to store data after every 20 pages
cars_dict={'url':[],
           'bodyType':[],
           'fuelType':[],
           'driveType':[],
           'name':[],
           'description':[],
           'location':[], 
           'traveled':[],
           'price':[],
           'color':[]
           
          }

# %%
#2.2 Scraping data from each individual car

# %%
## Extracting detailed information on cars from each page
def individual_car_info(car_url):
    x = False #set the flags which will be used to handle missing values while scraping the data
    y = False
    z = False
    result = requests.get(car_url) 
    soup = BeautifulSoup(result.content)
    sleep(2)
    #Store the value of 'Body Style', when found  else store 'N/A'
    for body in soup.find_all('li', class_='box--light-grey round'):
        
        if body.find_all('span')[0].get_text(strip=True) == 'Body Style':
            style =body.find_all('span')[1].get_text(strip=True) 
            x = True                
        if not x:
            style = 'Unknown'

        if body.find_all('span')[0].get_text(strip=True) == 'Fuel Type':
            y = True
            fuel = body.find_all('span')[1].get_text(strip=True)               
        if not y:
            fuel = 'Unknown'
   
        if body.find_all('span')[0].get_text(strip=True) == 'Drive Type':
            z = True
            drive = body.find_all('span')[1].get_text(strip=True)              
        if not z:
            drive = 'Unknown'
            
    return  style,fuel,drive

# %%
#2.3 Crawler to scrape the data from first 100 pages

# %%
for i in tqdm(range(1,101)): ## tqdm to show a smart progress meter 
    # send the http request to the server using get method and store the response in variable page
    page= requests.get(f'https://www.carpages.ca/used-cars/search/?num_results=50&p={i}') 

    # Convert the response content from bytes to string
    html_content = page.content.decode('utf-8')
    # Create a beautiful soup object, to interact with html code
    soup = BeautifulSoup(html_content, 'html.parser')


    car_blocks=soup.find_all('div', class_='media soft push-none rule') ## select whole block of car for each car(which is in div element)
    for car in car_blocks:# from each car block scrape the required data
        try:
            path=car.find('a', class_='media__img media__img--thumb').get('href')
            url='https://www.carpages.ca'+path
            ### Append to cars dictionary
            cars_dict['url'].append(url)
            bodyType,fuelType,driveType=(individual_car_info(url))
            cars_dict['bodyType'].append(bodyType)
            cars_dict['fuelType'].append(fuelType)
            cars_dict['driveType'].append(driveType)
        except:
            url=' '

        try:
            name=car.find('h4', class_='hN').get_text(strip=True)
            cars_dict['name'].append(name)
        except:
            name=' '
        try:
            description = car.find('hgroup', class_='push-half--bottom').h5.get_text(strip=True)
            cars_dict['description'].append(description)
        except:
            description = ' '
        try:
            location=car.find('hgroup', class_='vehicle__card--dealerInfo').get_text()
            cars_dict['location'].append(location)
        except:
            location=' '
        try:
            traveled = car.find('div', class_='grey l-column l-column--small-6 l-column--medium-4').get_text(strip=True)
            cars_dict['traveled'].append(traveled)
        except:
            traveled = ' '
        try:
            price=car.find('strong', class_='delta').get_text(strip=True)
            cars_dict['price'].append(price)
        except:
            price=' '
        try:        
            color=car.find_all('div', class_='grey l-column l-column--small-6 l-column--medium-4')[1].get_text(strip=True)
            cars_dict['color'].append(color)
        except: 
            color= ' '
    # create a dataframe for each page with 50 cars on each page
    cars_df = pd.DataFrame.from_dict(cars_dict,orient='index').transpose()
    cars_df.to_csv('car_listings.csv',mode = 'a',header=False)
    # Clear the dictionary and re initialize
    cars_dict.clear()
    cars_dict={ 'url':[],'bodyType':[],'fuelType':[],'driveType':[],'name':[],'description':[],'location':[],'traveled':[],
                    'price':[],'color':[]}
                
    sleep(random.randint(1,3))
# Out:
# 100%|██████████| 101/101 [3:53:10<00:00, 138.52s/it]

# %% [markdown]
# # 3.-Data-Cleanup

# %%
# Read data from car_listings.csv
cols=['url','bodyType','fuelType','driveType','name','features','location','mileage','price($)','color']
all_cars = pd.read_csv("car_listings.csv",index_col=0,names=cols)
print(all_cars.shape)
all_cars.head(10)

# %% [markdown]
# <b>The extracted data contains 10 columns and 4949 rows in all_cars df. All columns are of object datatype by default<b>

# %% [markdown]
# 3.1 Creating and Cleaning the columns values

# %% [markdown]
# 3.1.1: Computation on Column -name

# %%
#Extract manufacturing year, model, make from the name column
import re
def split_year(col):
    return re.search(r'^\d{4}',col).group()
def split_name(col):
    return re.search(r'^[\w\']+[\s]+([\w\']+)', col).group(1)
def split_make(col):
    return re.search(r'^(\w+\W+){2}(.+)', col).group(2)

# From name column split the year and model
all_cars['manufact_year'] = all_cars['name'].apply(split_year)
all_cars['make']= all_cars['name'].apply(split_name)
all_cars['model']= all_cars['name'].apply(split_make)

# %% [markdown]
# 3.1.2: Computation on Column -location

# %%
### removing the 'Buy From Home Options' and strip '\n's which is making csv file a weirdly formated
## find the column that contains 'Buy From Home Options'
matching_cols = all_cars.applymap(lambda x: 'Buy From Home Options' in str(x)).any()
print(matching_cols)
matching_cols = matching_cols[matching_cols == True].index
#matching_cols
# Out:
# url              False
# bodyType         False
# fuelType         False
# driveType        False
# name             False
# features         False
# location          True
# mileage          False
# price($)         False
# color            False
# manufact_year    False
# make             False
# model            False
# dtype: bool

# %%
# now find the rows and remove the unwanted text
all_cars['location'] = np.where(all_cars['location'].str.contains('Buy From Home Options'), 
                                all_cars['location'].str.replace('Buy From Home Options', '').str.strip(), 
                                all_cars['location'].str.strip())

# %% [markdown]
# Seperate the dealer name and location (city, province) from the location column

# %%
def dealer(x):
    return x.split('\n')[0]
def loc(x):
    return x.split('\n')[1]

# %%
def city(x):
    return x.split(',')[0]
def province(x):
    return x.split(',')[1]

# %%
all_cars['car_dealer']=all_cars['location'].apply(dealer)
all_cars['location']=all_cars['location'].apply(loc)
all_cars['city']=all_cars['location'].apply(city)
all_cars['province']=all_cars['location'].apply(province)

# %% [markdown]
# 3.1.3: Computation on Column -mileage

# %%
all_cars['mileage']=all_cars['mileage'].str.replace('CALL','')
all_cars['mileage']=all_cars['mileage'].str.strip('KM')

# %% [markdown]
# 3.1.4: Computation on Column -price

# %%
all_cars['price($)']=all_cars['price($)'].str.strip('$')

# %% [markdown]
# 3.1.5: Drop unnecessary and redundant columns

# %%
all_cars.drop('url', axis=1, inplace =True)
all_cars.drop('features',axis=1,inplace =True)

# %% [markdown]
# 3.2 Treating null values

# %%
# Check for null values
all_cars.isnull().sum()
# Out:
# bodyType           0
# fuelType           0
# driveType          0
# name               0
# location           0
# mileage            0
# price($)           0
# color            589
# manufact_year      0
# make               0
# model              0
# car_dealer         0
# city               0
# province           0
# dtype: int64

# %%
# Replace the missing values of color with unknown(for the purpose of displaying) instead of assigning any random color

# %%
all_cars['color'].fillna('Unknown',inplace=True)
all_cars['bodyType'].fillna('Unknown',inplace=True)
all_cars['fuelType'].fillna('Unknown',inplace=True)
all_cars['driveType'].fillna('Unknown',inplace=True)

# %% [markdown]
# 3.3 Changing the data type of the columns

# %%
#Summary of a DataFrame
all_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4949 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bodyType       4949 non-null   object
#  1   fuelType       4949 non-null   object
#  2   driveType      4949 non-null   object
#  3   name           4949 non-null   object
#  4   location       4949 non-null   object
#  5   mileage        4949 non-null   object
#  6   price($)       4949 non-null   object
#  7   color          4949 non-null   object
#  8   manufact_year  4949 non-null   object
#  9   make           4949 non-null   object
#  10  model          4949 non-null   object
#  11  car_dealer     4949 non-null   object
#  12  city           4949 non-null   object
#  13  province       4949 non-null   object
# dtypes: object(14)
# memory usage: 309.3+ KB

# %%
#Remove the commas from price and change the datatype to float
all_cars['price($)'] = all_cars['price($)'].str.replace(',','')
all_cars['price($)'] = all_cars['price($)'].astype(np.float64)

# %%
#Remove the commas from mileage and covert it to integer
all_cars['mileage']=[x.replace(',','') for x in all_cars['mileage']]
all_cars['mileage']=pd.to_numeric(all_cars['mileage'],errors='coerce') #By using ‘coerce’, the invalid parsing will be set as NaN.

# %%
# Convert the float value of manufacturing year to integer
all_cars['manufact_year'] = all_cars['manufact_year'].astype(int)

# %%
all_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4949 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bodyType       4949 non-null   object
#  1   fuelType       4949 non-null   object
#  2   driveType      4949 non-null   object
#  3   name           4949 non-null   object
#  4   location       4949 non-null   object
#  5   mileage        4491 non-null   float64
#  6   price($)       4949 non-null   float64
#  7   color          4949 non-null   object
#  8   manufact_year  4949 non-null   int32
#  9   make           4949 non-null   object
#  10  model          4949 non-null   object
#  11  car_dealer     4949 non-null   object
#  12  city           4949 non-null   object
#  13  province       4949 non-null   object
# dtypes: float64(2), int32(1), object(11)
# memory usage: 348.0+ KB

# %% [markdown]
# <h3>3.4 Converting the location into longitude and latitude </h3>

# %%
from geopy.geocoders import Nominatim

# %%
# initialize geolocator
geolocator = Nominatim(user_agent="cars_location")

# define function to geocode location
def geocode_location(location):
    location = geolocator.geocode(location)
    if location is not None:
        return location.latitude, location.longitude
    else:
        return None, None

# %%
# apply function to 'location' column
all_cars[['latitude', 'longitude']] = all_cars['location'].apply(geocode_location).apply(pd.Series)

# %%
# Drop the location which contains the city and province info keeping city, province column.
all_cars.drop('location', axis=1,inplace =True)

# %%
all_cars.tail()
# Out:
#            bodyType  fuelType          driveType  \
# 4944        Unknown  Gasoline    All Wheel Drive
# 4945        Unknown  Gasoline    All Wheel Drive
# 4946          Sedan  Gasoline  Front Wheel Drive
# 4947  Minivan / Van  Gasoline  Front Wheel Drive
# 4948   Pickup Truck   Unknown      4-Wheel Drive
#
#                               name   mileage  price($)      color  \
# 4944             2015 Cadillac SRX   96112.0   26995.0      Brown
# 4945            2021 Porsche Macan   11355.0   89995.0     Silver
# 4946             2018 Mazda MAZDA3   94000.0   25999.0      White
# 4947  2012 Chrysler Town & Country  101000.0   14999.0      Black
# 4948                 2022 RAM 3500       NaN   79910.0  Sport Red
#
#       manufact_year      make           model               car_dealer  \
# 4944           2015  Cadillac             SRX  Porsche Centre Edmonton
# 4945           2021   Porsche           Macan  Porsche Centre Edmonton
# 4946           2018     Mazda          MAZDA3        Trans Sell Motors
# 4947           2012  Chrysler  Town & Country        Trans Sell Motors
# 4948           2022       RAM            3500         Langley Chrysler
#
#           city province   latitude   longitude
# 4944  Edmonton       AB  53.546206 -113.491241
# 4945  Edmonton       AB  53.546206 -113.491241
# 4946  Edmonton       AB  53.546206 -113.491241
# 4947  Edmonton       AB  53.546206 -113.491241
# 4948    Surrey       BC  49.191303 -122.849143

# %%
all_cars.shape
# Out:
# (4949, 15)

# %% [markdown]
# #4.-Store the Cleaned Data

# %%
all_cars.to_csv("Cars_listings_final.csv",encoding = 'utf-8',index=False)

# %% [markdown]
# # 5.-Exploratory Data Analysis

# %% [markdown]
# 5.1 Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
all_cars=pd.read_csv('Cars_listings_final.csv')
all_cars[all_cars['mileage']==999999]
# Out:
#           bodyType  fuelType driveType                            name  \
# 3112  Pickup Truck  Gasoline   Unknown                 2011 Ford F-150
# 4701       Unknown  Gasoline   Unknown           2019 Keystone Montana
# 4703       Unknown  Gasoline   Unknown  2013 Freightliner CASCADIA 125
# 4704       Unknown  Gasoline   Unknown  2013 Freightliner CASCADIA 125
#
#        mileage  price($)  color  manufact_year          make         model  \
# 3112  999999.0    6900.0   Blue           2011          Ford         F-150
# 4701  999999.0   44000.0  Beige           2019      Keystone       Montana
# 4703  999999.0   12000.0  White           2013  Freightliner  CASCADIA 125
# 4704  999999.0   12000.0  White           2013  Freightliner  CASCADIA 125
#
#                car_dealer     city province   latitude   longitude
# 3112  Regal Auctions Ltd.  Calgary       AB  51.046095 -114.065465
# 4701  Regal Auctions Ltd.  Calgary       AB  51.046095 -114.065465
# 4703  Regal Auctions Ltd.  Calgary       AB  51.046095 -114.065465
# 4704  Regal Auctions Ltd.  Calgary       AB  51.046095 -114.065465

# %%
print(all_cars.shape)
all_cars.describe()
# Out:
# (4949, 15)
#             mileage       price($)  manufact_year     latitude    longitude
# count  4.491000e+03    4949.000000    4949.000000  4949.000000  4949.000000
# mean   8.653899e+04   38330.674272    2018.210548    46.618462   -90.816206
# std    1.668453e+05   33038.012716       4.584265     3.569687    18.032708
# min    1.000000e+00     200.000000    1962.000000    41.875000  -135.054932
# 25%    2.551100e+04   20500.000000    2016.000000    43.589623  -106.660767
# 50%    7.425600e+04   29999.000000    2019.000000    44.679971   -80.492781
# 75%    1.230000e+05   47500.000000    2022.000000    49.895537   -79.460762
# max    9.999999e+06  890648.000000    2023.000000    62.454081    -1.706340

# %%
all_cars[all_cars['manufact_year']==1962]
# Out:
#          bodyType fuelType driveType                     name  mileage  \
# 3295  Convertible  Unknown   Unknown  1962 Chevrolet Corvette  25652.0
#
#       price($)      color  manufact_year       make     model  \
# 3295  104051.0  Roman Red           1962  Chevrolet  Corvette
#
#               car_dealer           city province   latitude   longitude
# 3295  Sherwood Motorcars  Sherwood Park       AB  53.525696 -113.296631

# %%
all_cars[all_cars['price($)']==890648.000000]
# Out:
#      bodyType  fuelType        driveType                        name  mileage  \
# 3277    Coupe  Gasoline  All Wheel Drive  2022 Lamborghini Aventador    880.0
#
#       price($)               color  manufact_year         make      model  \
# 3277  890648.0  Rosso Efesto Shiny           2022  Lamborghini  Aventador
#
#               car_dealer           city province   latitude   longitude
# 3277  Sherwood Motorcars  Sherwood Park       AB  53.525696 -113.296631

# %% [markdown]
# Findings:
# 1) Mileage has minimum value 2km which is possible if the car is barely used,but the maximum value of the mileage was exceding the Upperbound when calculated statistically. This outliers needs to be handle at the early stage.
# 2) 1962 Chevrolet Corvette is a vintage car, can not be considered as outlier.
# 3) 2022 Lamborghini Aventador is the car with higher price. This is a genuine price hence not an outlier.

# %%
def lu_bounds(Q1,Q3):
    IQR=Q3-Q1
    up =Q3+(1.5 * IQR)
    lo = Q1-(1.5 * IQR)
    return lo, up

# %%
#Removing Mileage Outliers
Q1,Q3= all_cars['mileage'].quantile([.25, .75])
LB, UB = lu_bounds(Q1,Q3)
print(LB, UB)
#Removal of Mileage Outliers
allcars_noskew=all_cars[(all_cars['mileage']<= UB) & (all_cars['mileage']>=LB)]
# Out:
# -120722.5 269233.5

# %%
#Number of rows above the Upper Bound or the number of rows withvoutliers
len(all_cars[(all_cars['mileage']> UB)])
# Out:
# 81

# %%
len(all_cars[(all_cars['mileage']< LB)])
# Out:
# 0

# %%
#Show the statistical distribution of numerical values after removing outliers
print(allcars_noskew.shape)
allcars_noskew.describe()
# Out:
# (4313, 15)
#              mileage       price($)  manufact_year     latitude    longitude
# count    4313.000000    4313.000000    4313.000000  4313.000000  4313.000000
# mean    79468.485741   34781.755036    2018.018780    46.566033   -90.671659
# std     62814.920366   24720.697545       4.242736     3.554350    18.080721
# min         1.000000     200.000000    1962.000000    41.875000  -135.054932
# 25%     25341.000000   19999.000000    2016.000000    43.589623  -106.660767
# 50%     73642.000000   28995.000000    2019.000000    44.589593   -80.412732
# 75%    120754.000000   42062.000000    2021.000000    49.895537   -79.460762
# max    267000.000000  300680.000000    2023.000000    62.454081    -1.706340

# %%
### Correlation between each column
allcars_noskew.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                bodyType  fuelType  driveType      name   mileage  price($)  \
# bodyType       1.000000  0.031509   0.208415  0.028231 -0.011176  0.005511
# fuelType       0.031509  1.000000   0.172948  0.011120  0.033799  0.060037
# driveType      0.208415  0.172948   1.000000 -0.037880  0.054943 -0.051379
# name           0.028231  0.011120  -0.037880  1.000000  0.387944  0.211227
# mileage       -0.011176  0.033799   0.054943  0.387944  1.000000  0.222359
# price($)       0.005511  0.060037  -0.051379  0.211227  0.222359  1.000000
# color         -0.070907 -0.060735  -0.020011  0.133026 -0.005415  0.243573
# manufact_year -0.035465  0.007258   0.045441  0.093678  0.203808 -0.086250
# make          -0.032918  0.034070  -0.049285  0.181337  0.035028  0.062165
# model          0.035002  0.038789  -0.126846  0.468857  0.089382  0.127173
# car_dealer     0.056849  0.052665   0.073177  0.175297  0.327914  0.171904
# city          -0.019745  0.047806   0.004027  0.055436  0.159516  0.134278
# province       0.075541 -0.093585   0.013229  0.031133  0.036407  0.092811
# latitude      -0.018365  0.046835  -0.001862  0.054122  0.157691  0.137135
# longitude     -0.018365  0.046835  -0.001862  0.054122  0.157691  0.137135
#
#                   color  manufact_year      make     model  car_dealer  \
# bodyType      -0.070907      -0.035465 -0.032918  0.035002    0.056849
# fuelType      -0.060735       0.007258  0.034070  0.038789    0.052665
# driveType     -0.020011       0.045441 -0.049285 -0.126846    0.073177
# name           0.133026       0.093678  0.181337  0.468857    0.175297
# mileage       -0.005415       0.203808  0.035028  0.089382    0.327914
# price($)       0.243573      -0.086250  0.062165  0.127173    0.171904
# color          1.000000      -0.078378  0.062746  0.128385   -0.021754
# manufact_year -0.078378       1.000000  0.042806  0.040044    0.042322
# make           0.062746       0.042806  1.000000  0.304944    0.011473
# model          0.128385       0.040044  0.304944  1.000000    0.055095
# car_dealer    -0.021754       0.042322  0.011473  0.055095    1.000000
# city           0.128154      -0.042367  0.016658  0.036113    0.440450
# province       0.083476      -0.029373  0.000326 -0.003637   -0.065380
# latitude       0.131199      -0.043727  0.014721  0.034708    0.436761
# longitude      0.131199      -0.043727  0.014721  0.034708    0.436761
#
#                    city  province  latitude  longitude
# bodyType      -0.019745  0.075541 -0.018365  -0.018365
# fuelType       0.047806 -0.093585  0.046835   0.046835
# driveType      0.004027  0.013229 -0.001862  -0.001862
# name           0.055436  0.031133  0.054122   0.054122
# mileage        0.159516  0.036407  0.157691   0.157691
# price($)       0.134278  0.092811  0.137135   0.137135
# color          0.128154  0.083476  0.131199   0.131199
# manufact_year -0.042367 -0.029373 -0.043727  -0.043727
# make           0.016658  0.000326  0.014721   0.014721
# model          0.036113 -0.003637  0.034708   0.034708
# car_dealer     0.440450 -0.065380  0.436761   0.436761
# city           1.000000  0.091148  0.993049   0.993049
# province       0.091148  1.000000  0.096713   0.096713
# latitude       0.993049  0.096713  1.000000   1.000000
# longitude      0.993049  0.096713  1.000000   1.000000

# %%
#Removal of carmakers with less than 10 cars
allcars_noskew= allcars_noskew.groupby('make').filter(lambda x: len(x) > 9)
allcars_noskew= allcars_noskew.reset_index(drop=True)
allcars_noskew['make'].value_counts()
# Out:
# Ford          606
# Hyundai       393
# Nissan        332
# Chevrolet     325
# Toyota        311
# Honda         276
# Kia           267
# Mazda         188
# Volkswagen    173
# Dodge         166
# Jeep          156
# RAM           149
# GMC           147
# Mercedes      139
# BMW           119
# Subaru         73
# Audi           67
# Acura          56
# Buick          50
# Lexus          46
# Mitsubishi     41
# Infiniti       31
# Land           31
# Volvo          30
# Cadillac       28
# Chrysler       26
# Porsche        26
# Tesla          24
# MINI           23
# Lincoln        14
# Name: make, dtype: int64

# %% [markdown]
# 5.2 Bivariate Analysis

# %%
# price distribution over the listings
fig = plt.figure(figsize=(15,8))
ax = fig.gca()
sns.distplot(all_cars['price($)'],kde=True) # to get the line set kde to True
plt.xlabel('Price',fontsize=14)
plt.axvline(all_cars['price($)'].mean(),lw=3,ls='dashed',
            color='black',label='Mean price:'+'{0:.0f}'.format(np.mean(all_cars['price($)'])))
plt.title('Price Distribution over all Listings',fontsize=16)
plt.legend(loc='upper right',fontsize=16)
plt.show()
# Out:
# C:\Users\richa\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of mileage with skewed data
fig = plt.figure(figsize=(15,8))
ax = fig.gca()
sns.distplot(all_cars['mileage'],kde=True) # to get the line set kde to True
plt.xlabel('Miles',fontsize=14)
plt.axvline(all_cars['mileage'].mean(),lw=3,ls='dashed',
            color='black',label='Mean miles:'+'{0:.0f}'.format(np.mean(all_cars['mileage'])))
plt.title('Miles Distribution over all Listings',fontsize=16)
plt.legend(loc='upper right',fontsize=16)
plt.show()
# Out:
# C:\Users\richa\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# distribution of mileage with unskewed data
fig = plt.figure(figsize=(15,8))
ax = fig.gca()
sns.distplot(allcars_noskew['mileage'],kde=True) # to get the line set kde to True
plt.xlabel('Miles',fontsize=14)
plt.axvline(all_cars['mileage'].mean(),lw=3,ls='dashed',
            color='black',label='Mean miles:'+'{0:.0f}'.format(np.mean(all_cars['mileage'])))
plt.title('Miles Distribution over all Listings',fontsize=16)
plt.legend(loc='upper right',fontsize=16)
plt.show()
# Out:
# C:\Users\richa\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Correlation of the numerical data
plt.figure(figsize=(6,4))
sns.heatmap(all_cars[['price($)','mileage','manufact_year']].corr(),annot=True,cmap='crest');
#'coolwarm'

# %% [markdown]
# # Subplots

# %%
allcars_noskew = all_cars
plt.figure(figsize=(30,30))
#plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

sns.set(font_scale=2)
plt.subplot(3,2,1)
sns.boxplot(x='make',y='price($)',data=allcars_noskew[allcars_noskew['make']!= 'N/A'])
plt.xticks(rotation=90)
plt.subplot(3,2,2)
sns.boxplot(x='fuelType',y='price($)',data=allcars_noskew[allcars_noskew['fuelType']!='Unknown'])
plt.subplot(3,2,3)
plt.xticks(rotation=90)
sns.boxplot(x='bodyType',y='price($)',data=allcars_noskew[allcars_noskew['bodyType']!='Unknown'])
plt.subplot(3,2,4)
sns.boxplot(x='driveType',y='price($)',data=allcars_noskew[allcars_noskew['driveType']!='Unknown'])
plt.xticks(rotation=90)
plt.subplot(3,2,5)
sns.boxplot(x='manufact_year',y='price($)',data=allcars_noskew);
plt.xticks(rotation=90);
plt.tight_layout()

# %% [markdown]
# <h3> Price and manufacturing year</h3>

# %%
# plt.figure() creates a new figure or activate an existing figure.

# figsize is Width, height in inches.

fig_01 = plt.figure(figsize =(8,8),dpi=100 )
#The add_axes() method is used to add an axes to the figure.
#we have to specify the coordinates of it’s bottom left corner and its size. 
#The coordinates, width and height are proportional rather than absolute, so they are in the range between 0 and 1.
axes_01 = fig_01.add_axes([0,0.1,0.9,0.9])
axes_01.set_xlabel("Mileage ")
axes_01.set_ylabel("price($) ")
axes_01.set_title(" ")

axes_01.plot(allcars_noskew['manufact_year'].sort_values(ascending=False),allcars_noskew['price($)'],label = 'manufacturing year',color = 'r', lw=1, alpha=0.4, marker = 'o',
            markerfacecolor = 'y',markeredgecolor='b',markeredgewidth = 2)
#axes_01.plot(allcars_noskew['mileage'],allcars_noskew['price($)'],label = 'manufact_year',lw=4)
axes_01.legend(loc= 0)
#grid's grey color  = 0.6
#dashes = (5,2,1,2) (points, spaces, points, spaces)
axes_01.grid(True,color= '0.6',dashes = (5,2,1,2))
axes_01.set_facecolor('#efeeea')
axes_01.annotate("Outlier", xy = (2017,890000), xytext= (2000,800000), arrowprops=dict(facecolor='b',shrink= 0.05))
# Out:
# Text(2000, 800000, 'Outlier')

# %%
# zoom the relevant part
fig_01 = plt.figure(figsize =(8,10),dpi=100 )
axes_01 = fig_01.add_axes([0,0.1,0.9,0.9])
axes_01.set_xlabel("Mileage ")
axes_01.set_ylabel("price($) ")
axes_01.set_title(" ")

axes_01.plot(allcars_noskew['manufact_year'].sort_values(ascending=False),allcars_noskew['price($)'],label = 'manufacturing year',color = 'r', lw=1, alpha=0.4, marker = 'o',
            markerfacecolor = 'y',markeredgecolor='b',markeredgewidth = 2)

axes_01.set_xlim(2004,2020)
axes_01.set_ylim(0,1000000)
axes_01.annotate("Outlier", xy =(2017,890000), xytext= (2014,800000), arrowprops=dict(facecolor='b',shrink= 0.05))
# Out:
# Text(2014, 800000, 'Outlier')

# %%
sns.pairplot(temp_df,hue = 'fuelType',height=2.5,diag_kind="kde");
sns.set(font_scale=0.8)

# %%
#Most Popular Car Maker in Used Car Market with donut graph
allcars_noskew['make'].value_counts().nlargest(15).plot.pie(autopct='%1.1f%%', pctdistance=0.85,
        )
centre_circle= plt.Circle((0,0),0.5, fc='white')
fig = plt.gcf()
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
# Adding Title of chart
#plt.title('Top 15 autocar makers  ')
# Set aspect ratio to be equal
#ax.set_aspect('auto')
# Displaying Chart
plt.show()

# %% [markdown]
# ## Top 10 highest priced vehicles

# %%
#sort the data frame by the highest priced vehicles
all_cars_sortprice=allcars_noskew.sort_values(by='price($)',ascending=False)

# %%
top10_priced_cars = all_cars_sortprice.head(10)
top10_priced_cars
# Out:
#              bodyType  fuelType        driveType                         name  \
# 2871  SUV / Crossover  Gasoline  All Wheel Drive   2021 Mercedes-Benz G-Class
# 250   SUV / Crossover  Gasoline  All Wheel Drive   2017 Mercedes-Benz G-Class
# 2502  SUV / Crossover  Gasoline  All Wheel Drive         2022 Porsche Cayenne
# 4277      Convertible  Gasoline  All Wheel Drive  2022 Mercedes-Benz SL-Class
# 2879  SUV / Crossover  Gasoline  All Wheel Drive         2022 Porsche Cayenne
# 1595      Convertible  Gasoline  All Wheel Drive             2022 Porsche 911
# 2854          Unknown  Gasoline  All Wheel Drive             2021 Nissan GT-R
# 2838  SUV / Crossover  Gasoline  All Wheel Drive   2021 Mercedes-Benz G-Class
# 1868      Convertible  Gasoline  All Wheel Drive  2022 Mercedes-Benz SL-Class
# 2887  SUV / Crossover  Gasoline  All Wheel Drive   2021 Mercedes-Benz G-Class
#
#       mileage  price($)                                      color  \
# 2871  18799.0  300680.0                             Obsidian Black
# 250   13900.0  279910.0                                      Black
# 2502   2553.0  269888.0                                  Dark Grey
# 4277     90.0  263290.5  Obsidian Black Metallic w/ black soft top
# 2879   7933.0  260680.0                                Arctic Grey
# 1595   2300.0  259238.0                                      Chalk
# 2854    900.0  259238.0                        Pearl White Tricoat
# 2838  27185.0  245980.0                                      Black
# 1868   1168.0  239888.0                                      White
# 2887    280.0  233225.0                             Obsidian Black
#
#       manufact_year      make          model               car_dealer  \
# 2871           2021  Mercedes   Benz G-Class       Sherwood Motorcars
# 250            2017  Mercedes   Benz G-Class     Toronto Auto Brokers
# 2502           2022   Porsche        Cayenne        Car Nation Canada
# 4277           2022  Mercedes  Benz SL-Class  Mercedes-Benz Vancouver
# 2879           2022   Porsche        Cayenne       Sherwood Motorcars
# 1595           2022   Porsche            911       Sherwood Motorcars
# 2854           2021    Nissan           GT-R       Sherwood Motorcars
# 2838           2021  Mercedes   Benz G-Class            AA Canada Inc
# 1868           2022  Mercedes  Benz SL-Class        Car Nation Canada
# 2887           2021  Mercedes   Benz G-Class       Sherwood Motorcars
#
#                city province   latitude   longitude
# 2871  Sherwood Park       AB  53.525696 -113.296631
# 250         Vaughan       ON  43.794154  -79.526802
# 2502      Brantford       ON  43.140816  -80.263173
# 4277      Vancouver       BC  49.260872 -123.113952
# 2879  Sherwood Park       AB  53.525696 -113.296631
# 1595  Sherwood Park       AB  53.525696 -113.296631
# 2854  Sherwood Park       AB  53.525696 -113.296631
# 2838     North York       ON  43.754326  -79.449117
# 1868      Brantford       ON  43.140816  -80.263173
# 2887  Sherwood Park       AB  53.525696 -113.296631

# %% [markdown]
# # Most Popular Car Maker in Used Car Market

# %%
dist2 = data[data['property_tax'] < 50000]
ax3 = sns.jointplot(x='listed_price',y= 'property_tax',data=dist2,kind="reg", marker = 'x')
ax3.set_axis_labels('Listing Price', 'Property Tax')
#h.set_axis_labels('x', 'y', fontsize=16)
plt.grid() 
plt.show()

# %%
plt.figure(figsize = (15, 10))
allcars_noskew['make'].value_counts().nlargest(10).plot(kind='bar',title='Make Popularity',
                                                  color=['red','blue','green','y','k','m','c','brown',
                                                         'olive','cyan','indigo','magenta','olivedrab','coral','gold',
                                                         'darkgreen','navy','purple','lime'])
plt.title('Make Popularity',fontsize=20)
plt.xlabel('Make',fontsize=20);
plt.ylabel('Frequency Count',fontsize=20);

# %% [markdown]
# # Popular Colour in Used Car Market

# %%
import difflib

# %%
# To normalize the color
color_dict = {
    'black': '#000000',
    'white': '#FFFFFF',
    'red': '#FF0000',
    'green': '#008000',
    'blue': '#0000FF',
    'yellow': '#FFFF00',
    'orange': '#FFA500',
    'purple': '#800080'
    
}

# Normalize colors using the color_dict
allcars_noskew['color'] = allcars_noskew['color'].apply(lambda x: max(color_dict, key=lambda k: difflib.SequenceMatcher(None, k, x).ratio()))

# %%
dist2 = data[data['color'].value < 50000]
ax3 = sns.jointplot(x='listed_price',y= 'property_tax',data=dist2,kind="reg", marker = 'x')
ax3.set_axis_labels('Listing Price', 'Property Tax')
#h.set_axis_labels('x', 'y', fontsize=16)
plt.grid() 
plt.show()

# %%
allcars_noskew_filteredcolor= allcars_noskew[allcars_noskew['color']!='Unknown']
top10_colors = pd.DataFrame(allcars_noskew_filteredcolor['color'].value_counts(ascending = False).head(10))

plt.figure(figsize=(15, 15))
top10_colors.plot(kind='bar',color=['r', 'b', 'g', 'y', 'k', 'm', 'c', 'brown'])
plt.title('Popular Car Colors', fontsize=15)
plt.xlabel('Color', fontsize=15)
plt.ylabel('Number of Cars', fontsize=15)
plt.show();

# %%
import plotly.express as px
#df = px.allcars_noskew()
fig = px.scatter_3d(allcars_noskew, x='color', y='make', z='price($)',
                    color='color', symbol='price($)')
fig.show()

# %% [markdown]
# # Average Price of Each Car Maker

# %%
top_15=allcars_noskew.groupby(['make'])['price($)'].mean().sort_values(ascending=False).nlargest(15)
plt.figure(figsize=(20, 20))
ax=top_15.plot(kind='bar',color=['red', 'blue', 'green', 'orange', 'purple', 'gray', 'brown', 'pink', 
                                 'olive', 'cyan', 'magenta', 'teal', 'navy','maroon', 'coral'])
plt.title('Make vs Average Price')
plt.xlabel('Make')
plt.ylabel('Price')
plt.show()

# %%
sns.pairplot(allcars_noskew,hue = 'fuelType')

# %%
allcars_noskew.columns
# Out:
# Index(['bodyType', 'fuelType', 'driveType', 'name', 'mileage', 'price($)',
#        'color', 'manufact_year', 'make', 'model', 'car_dealer', 'city',
#        'province', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# # Price Analysis Between Electric and Hybrid Cars in a Calendar Year

# %%
sns.catplot(x='manufact_year',y='price($)',data=allcars_noskew,kind='bar',ci=False)
plt.xlabel('Manufacturing Year')
plt.ylabel('Price($)')
plt.title('Year vs Price')
plt.xticks(rotation=90);

# %% [markdown]
# # Influence of mileage on the price

# %%
# 3d plot to show the correlation between mileage, price, manufact_year
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
allcars_noskew= allcars_noskew.sample(3000)
ax.scatter(allcars_noskew['price($)'],allcars_noskew['manufact_year'], allcars_noskew['mileage'])
# set axis labels
ax.set_xlabel('price($)')
ax.set_ylabel('manufact_year')
ax.set_zlabel('mileage')
ax.tick_params(axis='both', labelsize=10)
# Separate the labels from the axis
ax.xaxis._axinfo['label']['space_factor'] = 4.0
# show the plot
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.relplot(x='mileage',y='price($)',data=allcars_noskew,kind='scatter',ci=False)
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.title('Influence of Manufacturing Year on the Price');

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.relplot(x='manufact_year',y='price($)',data=allcars_noskew,kind='scatter',ci=False)
plt.xlabel('Manufacturing Year')
plt.ylabel('Price')
plt.title('Influence of Manufacturing Year on the Price');

# %%
#Scatter plot for pricing over the manfacturing year and province
sns.scatterplot(x='manufact_year', y='price($)',data =allcars_noskew, hue = 'province', palette = 'YlGnBu')
# Out:
# <AxesSubplot:xlabel='manufact_year', ylabel='price($)'>

# %%
# Distribution of the listings over different cities
df = allcars_noskew.groupby(['latitude','longitude']).agg(No_of_listings= ('name','count'))
df = df.reset_index()
import plotly.express as px
px.set_mapbox_access_token('pk.eyJ1IjoiY2FycGFnZXMiLCJhIjoiY2xlZXNjZjR2MDRhaTNzcG1nNmNtYzM4aiJ9.mPoR_R6ZBQ3DG6PI8ljqSA')
fig = px.scatter_mapbox(df,
                        lat='latitude',
                        lon='longitude',
                        size='No_of_listings',
                        zoom=10, height=500)
                        
fig.show()
# Out:
# <div>                            <div id="ce78e58d-7d89-4135-ba51-74b702b9f495" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce78e58d-7d89-4135-ba51-74b702b9f495")) {                    Plotly.newPlot(                        "ce78e58d-7d89-4135-ba51-74b702b9f495",                        [{"hovertemplate":"No_of_listings=%{marker.size}<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>","lat":[41.875,42.2593155,42.31673970000001,42.405721899999996,42.5928652,42.779022,42.859494,42.8712485,42.884066,42.90591679999999,42.909716499999995,42.945283700000005,42.9480988,42.9497266,42.974613700000006,42.9832406,42.9922181,43.0248374,43.1054531,43.10656029999999,43.1408157,43.1579812,43.1931881,43.193234000000004,43.225693,43.2560802,43.3248924,43.3314156,43.3600536,43.447435999999996,43.451291,43.465269899999996,43.4749611,43.513671,43.532949,43.5460516,43.589623100000004,43.6435559,43.647009999999995,43.6534817,43.685832,43.692370200000006,43.70016079999999,43.7213619,43.731593,43.7430924,43.754326299999995,43.7729744,43.7848982,43.7941544,43.8003622,43.8161477,43.835765,43.8372648,43.8505287,43.85637070000001,43.859495200000005,43.8711909,43.879548,43.87982,43.8801166,43.8975558,43.9118312,43.9193171,43.946219899999996,43.9515755,43.9595998,43.96868585,43.9717581,44.000751799999996,44.056258,44.117126500000005,44.1539369,44.163326399999995,44.230686999999996,44.3048009,44.3150892,44.377413399999995,44.389311299999996,44.4296227,44.4358826,44.501400700000005,44.5678105,44.58180005,44.5837294,44.5895925,44.6092059,44.648618,44.679970700000005,44.750147,45.0154164,45.018441700000004,45.041508,45.0784875,45.140336600000005,45.270087200000006,45.27420120000001,45.278752000000004,45.305687899999995,45.3263919,45.344689100000004,45.345147999999995,45.366668,45.39715089999999,45.40683715,45.4208777,45.50318239999999,45.5042755,45.60558895,45.6180851,45.8260909,45.886430299999994,45.94780155,46.0945258,46.097995000000004,46.234953000000004,46.309211499999996,46.394306,46.49272,46.6350844,47.4252021,47.5614705,48.477472999999996,48.944151,48.95317,48.9592291,49.0312269,49.0521162,49.1039289,49.1428076,49.1589351,49.163168,49.183215399999995,49.1913033,49.2067726,49.2433804,49.2608724,49.262164299999995,49.282224299999996,49.3206294,49.4478873,49.472114700000006,49.5107477,49.530557,49.63177895,49.809661,49.8511143,49.868087,49.8879177,49.8955367,49.9011596,49.90597555,49.9374945,50.000678,50.023071,50.04303,50.1001332,50.146986,50.2849138,50.401515,50.44876,50.5801916,50.7005059,51.0460954,51.153509,51.28597,51.4687094,51.845383899999995,52.131802,52.192780299999995,52.26906279999999,52.4727515,53.201097,53.2174924,53.222480000000004,53.4589412,53.5256963,53.546205500000006,55.281074100000005,56.23253295,56.2524039,56.9234624,60.721571],"legendgroup":"","lon":[-82.492891325,-82.43226820000001,-83.03733890000001,-82.1853837,-82.3873866,-81.1929882,-80.7265015,-79.4535176,-81.0880562,-79.61884570000001,-81.49573170000001,-81.4321521,-81.8802713,-79.8585358,-82.4065585,-81.243372,-79.2484192,-79.3610045,-81.1401989,-79.06390390000001,-80.2631733,-79.2441003,-79.5606834,-80.384281,-79.976692,-79.8728583,-79.7966835,-79.8956803,-80.3123023,-79.66667199999999,-80.49278149999999,-80.52229609999999,-80.4127316,-79.882817,-80.554627,-80.2493276,-79.64438790000001,-79.56563259999999,-80.017604,-79.38393470000001,-79.75993659999999,-79.4653558,-79.5162474,-79.5655129,-80.95288199999999,-81.7110949,-79.44911696639593,-79.25764790000001,-79.59238549999999,-79.52680229999999,-79.49938759999999,-79.4245925,-79.090576,-66.1157,-79.02088140000001,-79.3376825,-79.5068973,-81.1092278,-79.73826,-78.9421751,-79.43929250000001,-78.8635324,-80.8690127,-80.0973754,-80.1042319,-78.2939704,-78.1677784,-78.65135738273909,-79.245 ...

# %%
allcars_noskew.columns
# Out:
# Index(['bodyType', 'fuelType', 'driveType', 'name', 'mileage', 'price($)',
#        'color', 'manufact_year', 'make', 'model', 'car_dealer', 'city',
#        'province', 'latitude', 'longitude'],
#       dtype='object')

# %%
df = allcars_noskew.groupby('bodyType').agg(count = ('name','count'))
df = df.reset_index()
s = df['count'].sum()
percentage = df['count']/s
print(percentage)
df
# Out:
# 0     0.000454
# 1     0.001134
# 2     0.002494
# 3     0.008390
# 4     0.018594
# 5     0.000227
# 6     0.046939
# 7     0.040136
# 8     0.000227
# 9     0.000227
# 10    0.139002
# 11    0.349660
# 12    0.270748
# 13    0.000907
# 14    0.001361
# 15    0.109751
# 16    0.009524
# 17    0.000227
# Name: count, dtype: float64
#                  bodyType  count
# 0       Class A Motorhome      2
# 1              Commercial      5
# 2          Commercial Van     11
# 3             Convertible     37
# 4                   Coupe     82
# 5              Dump Truck      1
# 6               Hatchback    207
# 7           Minivan / Van    177
# 8              Motorcycle      1
# 9                Off-road      1
# 10           Pickup Truck    613
# 11        SUV / Crossover   1542
# 12                  Sedan   1194
# 13             Sport Bike      4
# 14         Travel Trailer      6
# 15                Unknown    484
# 16                  Wagon     42
# 17  Wheelchair Accessible      1

# %%
df = allcars_noskew.groupby('fuelType').agg(count = ('name','count'), percentage = ())
df = df.reset_index()
s = df['count'].sum()
percentage = df['count']/s
print(percentage)
df
# Out:
# 0    0.021542
# 1    0.011338
# 2    0.014512
# 3    0.694558
# 4    0.020181
# 5    0.237868
# Name: count, dtype: float64
#     fuelType  count
# 0     Diesel     95
# 1   Electric     50
# 2  Flex Fuel     64
# 3   Gasoline   3063
# 4     Hybrid     89
# 5    Unknown   1049

# %%
df = allcars_noskew.groupby('manufact_year').agg(count = ('name','count'))
df = df.reset_index()
s = df['count'].sum()
print(s)
percentage = df['count']/s
print(percentage)
df
# Out:
# 4410
# 0     0.000227
# 1     0.000227
# 2     0.000227
# 3     0.000227
# 4     0.000227
# 5     0.000680
# 6     0.000454
# 7     0.000680
# 8     0.000907
# 9     0.002721
# 10    0.002948
# 11    0.004082
# 12    0.008390
# 13    0.008617
# 14    0.008163
# 15    0.017914
# 16    0.017687
# 17    0.021315
# 18    0.034240
# 19    0.041497
# 20    0.057823
# 21    0.072109
# 22    0.088209
# 23    0.104989
# 24    0.111565
# 25    0.102268
# 26    0.077324
# 27    0.058503
# 28    0.155782
# Name: count, dtype: float64
#     manufact_year  count
# 0            1962      1
# 1            1966      1
# 2            1970      1
# 3            1984      1
# 4            1997      1
# 5            1999      3
# 6            2001      2
# 7            2002      3
# 8            2003      4
# 9            2004     12
# 10           2005     13
# 11           2006     18
# 12           2007     37
# 13           2008     38
# 14           2009     36
# 15           2010     79
# 16           2011     78
# 17           2012     94
# 18           2013    151
# 19           2014    183
# 20           2015    255
# 21           2016    318
# 22           2017    389
# 23           2018    463
# 24           2019    492
# 25           2020    451
# 26           2021    341
# 27           2022    258
# 28           2023    687

# %%
allcars_noskew[allcars_noskew['mileage']==1]
# Out:
#              bodyType  fuelType      driveType                          name  \
# 284    Travel Trailer   Unknown        Unknown       2014 Keystone RV Cougar
# 285    Travel Trailer   Unknown        Unknown   2015 Keystone RV Springdale
# 303           Unknown  Gasoline  4-Wheel Drive      2023 Jeep Grand Cherokee
# 715   SUV / Crossover  Gasoline  4-Wheel Drive        2023 Ford Bronco Sport
# 820    Travel Trailer   Unknown        Unknown        2015 Palomino Columbus
# 1201     Pickup Truck  Gasoline  4-Wheel Drive               2023 Ford F-150
# 1202     Pickup Truck  Gasoline  4-Wheel Drive              2023 Ford Ranger
# 1203  SUV / Crossover  Gasoline  4-Wheel Drive            2023 Ford Explorer
# 1442          Unknown    Hybrid  4-Wheel Drive            2023 Jeep Wrangler
# 1443          Unknown    Hybrid  4-Wheel Drive            2023 Jeep Wrangler
# 1444     Pickup Truck  Gasoline  4-Wheel Drive            2023 Jeep Wrangler
# 1461     Pickup Truck  Gasoline  4-Wheel Drive         2022 RAM 1500 Classic
# 2192   Travel Trailer   Unknown        Unknown    2016 SHADOW CRUISER 313BHS
# 2924   Travel Trailer   Unknown        Unknown      2018 Keystone RV Hideout
# 2925   Travel Trailer   Unknown        Unknown  2015 i-GO by Evergreen 280QB
# 4702          Unknown  Gasoline        Unknown           2022 Segway Snarler
#
#       mileage  price($)                                color  manufact_year  \
# 284       1.0   29800.0                                White           2014
# 285       1.0   24800.0  GREY METALLIC WITH SPECIAL GRAPHICS           2015
# 303       1.0   92623.0                        Silver Zynith           2023
# 715       1.0   44899.0      Hot Pepper Red Tinted Clearcoat           2023
# 820       1.0   44800.0   TAN METALLIC WITH SPECIAL GRAPHICS           2015
# 1201      1.0   66655.0                         Oxford White           2023
# 1202      1.0   57355.0             Carbonized Grey Metallic           2023
# 1203      1.0   60380.0  Rapid Red Metallic Tinted Clearcoat           2023
# 1442      1.0   69698.0              Bright White Clear Coat           2023
# 1443      1.0   69698.0               Sarge Green Clear Coat           2023
# 1444      1.0   61028.0                     Black Clear Coat           2023
# 1461      1.0   69635.0                                  Red           2022
# 2192      1.0   34800.0            TAN WITH SPECIAL GRAPHICS           2016
# 2924      1.0   28800.0            TAN WITH SPECIAL GRAPHICS           2018
# 2925      1.0   27800.0          WHITE WITH SPECIAL GRAPHICS           2015
# 4702      1.0    8200.0                                 Grey           2022
#
#           make                  model                      car_dealer  \
# 284   Keystone              RV Cougar  Winnipeg West Automotive Group
# 285   Keystone          RV Springdale  Winnipeg West Automotive Group
# 303       Jeep         Grand Cherokee               Listowel Chrysler
# 715       Ford           Bronco Sport             Capital Ford Regina
# 820   Palomino               Columbus  Winnipeg West Automotive Group
# 1201      Ford                  F-150             Capital Ford Regina
# 1202      Ford                 Ranger             Capital Ford Regina
# 1203      Ford               Explorer             Capital Ford Regina
# 1442      Jeep               Wrangler               Listowel Chrysler
# 1443      Jeep               Wrangler               Listowel Chrysler
# 1444      Jeep               Wrangler               Listowel Chrysler
# 1461       RAM           1500 Classic                    Aurora Dodge
# 2192    SHADOW         CRUISER 313BHS  Winnipeg West Automotive Group
# 2924  Keystone             RV Hideout  Winnipeg West Automotive Group
# 2925         i  GO by Evergreen 280QB  Winnipeg West Automotive Group
# 4702    Segway                Snarler             Regal Auctions Ltd.
#
#              city province   latitude   longitude
# 284    Headingley       MB  49.868087  -97.391052
# 285    Headingley       MB  49.868087  -97.391052
# 303      Listowel       ON  43.731593  -80.952882
# 715        Regina       SK  50.448760 -104.617310
# 820    Headingley       MB  49.868087  -97.391052
# 1201       Regina       SK  50.448760 -104.617310
# 1202       Regina       SK  50.448760 -104.617310
# 1203       Regina       SK  50.448760 -104.617310
# 1442     Listowel       ON  43.731593  -80.952882
# 1443     Listowel       ON  43.731593  -80.952882
# 1444     Listowel       ON  43.731593  -80.952882
# 1461  Yellowknife       NT  62.454081 -114.377385
# 2192   Headingley       MB  49.868087  -97.391052
# 2924   Headingley       MB  49.868087  -97.391052
# 2925   Headingley       MB  49.868087  -97.391052
# 4702      Calgary       AB  51.046095 -114.065465

# %%
Conclusion:
1) There is moderate corelation between mileage and price, manufacturing year and  price.
2) In the listings, 34% cars are the SUV's.
3) Maximum car are Gasoline based, which is 69% of the total listings.
4) All Wheel Drive leads with 32%
